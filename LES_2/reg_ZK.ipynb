# %% [markdown]
# # Забайкальский край

# %%
import os
import geopandas as gpd

# Корректное отображение графиков в jupyter
# %matplotlib inline

# Текущая директория
ROOT_PATH = os.path.abspath(os.curdir)

# %%
# чтение файла .shp
fp = os.path.join(ROOT_PATH,r'data\rus\gran_reg1.shx')
gdf = gpd.read_file(fp)
gdf.head()
# Out:
#       OSM_ID                          NAME ADMIN_LVL  ID_1      DT_OBR  \
# 0  -194924.0         Красночикойский район         6    13  1933-01-01
# 1  -194940.0  Петровск-Забайкальский район         6    21  1926-01-04
# 2 -1754048.0               Хилокский район         6    27  1935-02-11
# 3 -1742666.0               Кыринский район         6    14  1926-01-04
# 4 -1754047.0              Улётовский район         6    26  1926-01-04
#
#        REG_NUM POPULATION ADM_CNT  \
# 0  RU 92513000       None    None
# 1  RU 92521000       None    None
# 2  RU 92527000       None    None
# 3  RU 92514000       None    None
# 4  RU 92526000       None    None
#
#                                             geometry
# 0  POLYGON ((107.73338 50.11055, 107.74180 50.116...
# 1  POLYGON ((108.09007 50.77555, 108.09208 50.778...
# 2  POLYGON ((109.30976 51.19475, 109.31100 51.197...
# 3  POLYGON ((109.39000 49.30027, 109.40258 49.309...
# 4  POLYGON ((110.89757 49.83994, 110.90595 49.839...

# %%
# Название колонок 
gdf.columns.values
# Out:
# array(['OSM_ID', 'NAME', 'ADMIN_LVL', 'ID_1', 'DT_OBR', 'REG_NUM',
#        'POPULATION', 'ADM_CNT', 'geometry'], dtype=object)

# %%
gdf.shape
# Out:
# (31, 9)

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OSM_ID      31 non-null     float64
#  1   NAME        31 non-null     object
#  2   ADMIN_LVL   31 non-null     object
#  3   ID_1        31 non-null     int64
#  4   DT_OBR      31 non-null     object
#  5   REG_NUM     31 non-null     object
#  6   POPULATION  0 non-null      object
#  7   ADM_CNT     0 non-null      object
#  8   geometry    31 non-null     geometry
# dtypes: float64(1), geometry(1), int64(1), object(6)
# memory usage: 2.3+ KB

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf['area_reg'] = round(gdf.geometry.area, 2)
# Out:
# C:\Anaconda3\envs\python-gis\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
gdf.at[0, "geometry"]

# %%
# Площадь 
for index, row in gdf[:5].iterrows():
    print("Площадь:",round(row["geometry"].area, 0), "кв.м.")
# Out:
# Площадь: 4.0 кв.м.
# Площадь: 1.0 кв.м.
# Площадь: 2.0 кв.м.
# Площадь: 2.0 кв.м.
# Площадь: 2.0 кв.м.

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.area
# Out:
# C:\Anaconda3\envs\python-gis\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# 0     3.558771
# 1     1.154004
# 2     1.920987
# 3     1.992042
# 4     2.064952
# 5     2.135604
# 6     0.942959
# 7     0.863878
# 8     1.053673
# 9     0.793629
# 10    7.078572
# 11    0.754376
# 12    0.817477
# 13    0.801122
# 14    0.793243
# 15    8.258196
# 16    1.126799
# 17    0.713347
# 18    0.635871
# 19    1.722779
# 20    0.661322
# 21    2.108442
# 22    0.913411
# 23    0.568035
# 24    0.641172
# 25    6.039330
# 26    0.647728
# 27    1.897597
# 28    3.423706
# 29    0.415098
# 30    1.171495
# dtype: float64
